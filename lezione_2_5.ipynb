# %%
#variabile che contiene dei libri. ogni libro ha il titolo, l'anno di publicazioen e l'autore
lista_libri=[{"ID":1,"titolo":"harry poter","anno":2000,"autore":"j.k rowling"},
             {"ID":2,"titolo":"game of throne","anno":2025,"autore":"j.r.r martins"},
             {"ID":3,"titolo":"animali fantastici","anno":1980,"autore":"j.k rowling"}]

indice=4

#print(lista_libri[1]["titolo"])

"""for libro in lista_libri:
    print(f"titolo libro:  {libro["titolo"]} | anno di publicazione:{libro["anno"]}")"""

#creare una funzione che stampa i libri
def stampa_libri(lista):
    for libro in lista:
       print(f"ID: {libro["ID"]}  titolo libro:  {libro["titolo"]} | anno di publicazione:{libro["anno"]}")

stampa_libri(lista_libri)

#funzione che aggiunge nuovo libro, con id automatico
def add_book(titolo:str,anno:int,autore:str):
    flag=False #non c'è il libro
    for libro in lista_libri:
        if libro["titolo"] == titolo: 
           flag=True
    
    if flag == True:
       print(f"{titolo} gia presente nel database")
    else:    
                    indice=len(lista_libri)+1
                    print("inserimento libro in corso...")
                    print(indice)
                    voce={"ID":indice,"titolo":titolo,"anno":anno,"autore":autore}
                    lista_libri.append(voce)
                    print("libro inserito con successo.")

add_book("piccolo principe",1943,"antoinette")  
stampa_libri(lista_libri)
add_book("la bibbia",980,"pietro")  
stampa_libri(lista_libri)
add_book("la bibbia",980,"pietro")
stampa_libri(lista_libri)

#funzione per rimuovere un libro
def remove_libro(titolo):
     for libro in lista_libri:
          if libro["titolo"] == titolo:
               lista_libri.remove(libro)
               print("libro cancellato")

remove_libro("animali fantastici")  
stampa_libri(lista_libri)
# Out:
# ID: 1  titolo libro:  harry poter | anno di publicazione:2000
# ID: 2  titolo libro:  game of throne | anno di publicazione:2025
# ID: 3  titolo libro:  animali fantastici | anno di publicazione:1980
# inserimento libro in corso...
# 4
# libro inserito con successo.
# ID: 1  titolo libro:  harry poter | anno di publicazione:2000
# ID: 2  titolo libro:  game of throne | anno di publicazione:2025
# ID: 3  titolo libro:  animali fantastici | anno di publicazione:1980
# ID: 4  titolo libro:  piccolo principe | anno di publicazione:1943
# inserimento libro in corso...
# 5
# libro inserito con successo.
# ID: 1  titolo libro:  harry poter | anno di publicazione:2000
# ID: 2  titolo libro:  game of throne | anno di publicazione:2025
# ID: 3  titolo libro:  animali fantastici | anno di publicazione:1980
# ID: 4  titolo libro:  piccolo principe | anno di publicazione:1943
# ID: 5  titolo libro:  la bibbia | anno di publicazione:980
# la bibbia gia presente nel database
# ID: 1  titolo libro:  harry poter | anno di publicazione:2000
# ID: 2  titolo libro:  game of throne | anno di publicazione:2025
# ID: 3  titolo libro:  animali fantastici | anno di publicazione:1980
# ID: 4  titolo libro:  piccolo principe | anno di publicazione:1943
# ID: 5  titolo libro:  la bibbia | anno di publicazione:980
# libro cancellato
# ID: 1  titolo libro:  harry poter | anno di publicazione:2000
# ID: 2  titolo libro:  game of throne | anno di publicazione:2025
# ID: 4  titolo libro:  piccolo principe | anno di publicazione:1943
# ID: 5  titolo libro:  la bibbia | anno di publicazione:980
